# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('D:\Earth.Org\TemperatureChange_Cities\daily_temperature_1000_cities_1980_2020.csv', skiprows=12)
data
# Out:
#          datetime      0      1      2      3      4      5      6      7  \
# 0      1980-01-01   4.16   1.48  11.35  23.40  17.86  13.74   9.10  20.47
# 1      1980-01-02   4.06   1.00  10.01  22.67  18.65  12.85   6.40  19.37
# 2      1980-01-03   7.12  -3.23   9.67  22.30  18.42  10.50   5.43  18.71
# 3      1980-01-04   9.23  -1.81  10.12  23.40  19.21  10.87   2.29  18.76
# 4      1980-01-05   3.20  -4.31  10.81  23.98  21.34  11.03   2.40  18.62
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14879  2020-09-26  19.72  20.83  15.86  27.69  25.29  28.99  22.92  28.75
# 14880  2020-09-27  20.65  22.14  16.93  26.55  23.83  28.93  23.08  29.71
# 14881  2020-09-28  21.68  21.12  13.58  26.99  20.90  29.25  22.78  29.96
# 14882  2020-09-29  18.89  19.82  11.50  27.10  24.79  28.68  22.43  29.85
# 14883  2020-09-30  20.59  20.02  15.58  27.33  28.66  28.15  22.27  29.62
#
#            8  ...    990    991    992    993    994    995    996    997  \
# ...

# %%
key = pd.read_csv('D:\Earth.Org\TemperatureChange_Cities\daily_temperature_1000_cities_1980_2020.csv', nrows=7)
key
# Out:
#           Key         0              1            2       3          4      5  \
# 0        city     Tokyo       New York  Mexico City  Mumbai  São Paulo  Delhi
# 1  city_ascii     Tokyo       New York  Mexico City  Mumbai  Sao Paulo  Delhi
# 2         lat    35.685        40.6943      19.4424  19.017   -23.5587  28.67
# 3         lng  139.7514       -73.9249      -99.131  72.857    -46.625  77.23
# 4     country     Japan  United States       Mexico   India     Brazil  India
# 5        iso2        JP             US           MX      IN         BR     IN
# 6        iso3       JPN            USA          MEX     IND        BRA    IND
#
#           6        7              8  ...       990       991      992  \
# 0  Shanghai  Kolkata    Los Angeles  ...  Bilāspur  Sargodha  Leipzig
# 1  Shanghai  Kolkata    Los Angeles  ...  Bilaspur  Sargodha  Leipzig
# 2   31.2165   22.495        34.1139  ...   22.0904   32.0854  51.3354
# ...

# %%
key = key.set_index('Key', drop=True)
key = key.T
key
# Out:
# Key               city         city_ascii       lat       lng        country  \
# 0                Tokyo              Tokyo    35.685  139.7514          Japan
# 1             New York           New York   40.6943  -73.9249  United States
# 2          Mexico City        Mexico City   19.4424   -99.131         Mexico
# 3               Mumbai             Mumbai    19.017    72.857          India
# 4            São Paulo          Sao Paulo  -23.5587   -46.625         Brazil
# ..                 ...                ...       ...       ...            ...
# 995           Yangzhou           Yangzhou      32.4    119.43          China
# 996       Novokuznetsk       Novokuznetsk     53.75    87.115         Russia
# 997            Latakia            Latakia     35.54     35.78          Syria
# 998  Heroica Matamoros  Heroica Matamoros     25.88     -97.5         Mexico
# 999           Göteborg           Goteborg     57.75      12.0         Sweden
#
# Key iso2 iso3
# 0     JP  JPN
# ...

# %%
for i in range(0,1000):
    data = data.rename(columns={f'{i}': key.iloc[i,1]})
data
# Out:
#          datetime  Tokyo  New York  Mexico City  Mumbai  Sao Paulo  Delhi  \
# 0      1980-01-01   4.16      1.48        11.35   23.40      17.86  13.74
# 1      1980-01-02   4.06      1.00        10.01   22.67      18.65  12.85
# 2      1980-01-03   7.12     -3.23         9.67   22.30      18.42  10.50
# 3      1980-01-04   9.23     -1.81        10.12   23.40      19.21  10.87
# 4      1980-01-05   3.20     -4.31        10.81   23.98      21.34  11.03
# ...           ...    ...       ...          ...     ...        ...    ...
# 14879  2020-09-26  19.72     20.83        15.86   27.69      25.29  28.99
# 14880  2020-09-27  20.65     22.14        16.93   26.55      23.83  28.93
# 14881  2020-09-28  21.68     21.12        13.58   26.99      20.90  29.25
# 14882  2020-09-29  18.89     19.82        11.50   27.10      24.79  28.68
# 14883  2020-09-30  20.59     20.02        15.58   27.33      28.66  28.15
#
#        Shanghai  Kolkata  Los Angeles  ...  Bilaspur  Sargodha  Leipzig  \
# ...

# %%
plt.plot(data['datetime'], data['Tokyo'])
# Out:
# Error in callback <function flush_figures at 0x000002184EFB7DC0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\miniconda3\envs\DS\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\miniconda3\envs\DS\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
key[key.city == 'Barcelona']
# Out:
# Key       city city_ascii      lat     lng    country iso2 iso3
# 56   Barcelona  Barcelona  41.3833  2.1834      Spain   ES  ESP
# 915  Barcelona  Barcelona  10.1304  -64.72  Venezuela   VE  VEN

# %%
years = pd.to_datetime(data['datetime'])
data['datetime'] = years
data['year'] = years.apply(lambda x: x.year)
years = list(set(years.apply(lambda x: x.year)))
years
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
data
# Out:
#         datetime  Tokyo  New York  Mexico City  Mumbai  Sao Paulo  Delhi  \
# 0     1980-01-01   4.16      1.48        11.35   23.40      17.86  13.74
# 1     1980-01-02   4.06      1.00        10.01   22.67      18.65  12.85
# 2     1980-01-03   7.12     -3.23         9.67   22.30      18.42  10.50
# 3     1980-01-04   9.23     -1.81        10.12   23.40      19.21  10.87
# 4     1980-01-05   3.20     -4.31        10.81   23.98      21.34  11.03
# ...          ...    ...       ...          ...     ...        ...    ...
# 14879 2020-09-26  19.72     20.83        15.86   27.69      25.29  28.99
# 14880 2020-09-27  20.65     22.14        16.93   26.55      23.83  28.93
# 14881 2020-09-28  21.68     21.12        13.58   26.99      20.90  29.25
# 14882 2020-09-29  18.89     19.82        11.50   27.10      24.79  28.68
# 14883 2020-09-30  20.59     20.02        15.58   27.33      28.66  28.15
#
#        Shanghai  Kolkata  Los Angeles  ...  Sargodha  Leipzig  Tinnevelly  \
# ...

# %%
df = pd.DataFrame()
df['year'] = years
i = 0
for c in key['city_ascii']:
    i += 1
    li = []
    for y in years:
        temp = data.loc[ data['year'] == y, f'{c}']
        li.append(temp.sum() / len(temp))
    df[f'{c}'] = li
print(i)
df.to_csv('D:\\Earth.Org\\TemperatureChange_Cities\\1000_cities_1980_2020.csv')
df
# Out:
# 1000
#     year      Tokyo   New York  Mexico City     Mumbai  Sao Paulo      Delhi  \
# 0   1980  14.685792  11.573579    14.669836  26.515109  19.559645  24.894508
# 1   1981  14.380466  11.700493    14.427342  26.393973  19.078301  24.815041
# 2   1982  15.323151  11.634219    15.175808  26.352301  19.395781  24.160110
# 3   1983  15.024575  12.438795    14.956411  25.934110  19.625671  23.400137
# 4   1984  14.168197  12.038388    14.295328  26.111038  19.870301  24.317022
# 5   1985  15.139260  12.218192    14.081123  26.018164  19.451836  24.715753
# 6   1986  14.543096  12.053836    14.205699  26.320027  19.892849  24.190548
# 7   1987  15.545890  12.007973    14.735425  26.754740  19.637973  25.670575
# 8   1988  14.870902  11.621257    14.802568  26.498333  19.255082  25.136120
# 9   1989  15.737918  11.656301    14.533781  26.202192  19.041562  24.419342
# 10  1990  16.450274  13.056740    14.643096  26.249945  19.654219  24.527973
# ...

# %%
df_change = pd.DataFrame()
df_change = df
df_change
# Out:
#     year      Tokyo   New York  Mexico City     Mumbai  Sao Paulo      Delhi  \
# 0   1980  14.685792  11.573579    14.669836  26.515109  19.559645  24.894508
# 1   1981  14.380466  11.700493    14.427342  26.393973  19.078301  24.815041
# 2   1982  15.323151  11.634219    15.175808  26.352301  19.395781  24.160110
# 3   1983  15.024575  12.438795    14.956411  25.934110  19.625671  23.400137
# 4   1984  14.168197  12.038388    14.295328  26.111038  19.870301  24.317022
# 5   1985  15.139260  12.218192    14.081123  26.018164  19.451836  24.715753
# 6   1986  14.543096  12.053836    14.205699  26.320027  19.892849  24.190548
# 7   1987  15.545890  12.007973    14.735425  26.754740  19.637973  25.670575
# 8   1988  14.870902  11.621257    14.802568  26.498333  19.255082  25.136120
# 9   1989  15.737918  11.656301    14.533781  26.202192  19.041562  24.419342
# 10  1990  16.450274  13.056740    14.643096  26.249945  19.654219  24.527973
# ...

# %%
for y in range(41):
    df_change.iloc[40-y,1:] = df_change.iloc[40-y,1:] - df_change.iloc[40-y-1,1:]
df_change
# Out:
#     year      Tokyo  New York  Mexico City     Mumbai  Sao Paulo      Delhi  \
# 0   1980  13.425643  9.485313    13.964524  26.293285  20.798843  23.843902
# 1   1981  -0.305327  0.126914    -0.242494  -0.121137  -0.481343  -0.079467
# 2   1982   0.942685 -0.066274     0.748466  -0.041671   0.317479  -0.654932
# 3   1983  -0.298575  0.804575    -0.219397  -0.418192   0.229890  -0.759973
# 4   1984  -0.856379 -0.400407    -0.661083   0.176929   0.244629   0.916885
# 5   1985   0.971064  0.179804    -0.214205  -0.092874  -0.418465   0.398732
# 6   1986  -0.596164 -0.164356     0.124575   0.301863   0.441014  -0.525205
# 7   1987   1.002795 -0.045863     0.529726   0.434712  -0.254877   1.480027
# 8   1988  -0.674989 -0.386716     0.067144  -0.256406  -0.382891  -0.534455
# 9   1989   0.867016  0.035045    -0.268787  -0.296142  -0.213520  -0.716778
# 10  1990   0.712356  1.400438     0.109315   0.047753   0.612658   0.108630
# ...

# %%
df_change = df_change.set_index('year')
df_change.loc[1981:,'Tokyo'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df = pd.read_csv('D:\\Earth.Org\\TemperatureChange_Cities\\1000_cities_1980_2020.csv')
df
# Out:
#     Unnamed: 0  year      Tokyo   New York  Mexico City     Mumbai  Sao Paulo  \
# 0            0  1980  14.685792  11.573579    14.669836  26.515109  19.559645
# 1            1  1981  14.380466  11.700493    14.427342  26.393973  19.078301
# 2            2  1982  15.323151  11.634219    15.175808  26.352301  19.395781
# 3            3  1983  15.024575  12.438795    14.956411  25.934110  19.625671
# 4            4  1984  14.168197  12.038388    14.295328  26.111038  19.870301
# 5            5  1985  15.139260  12.218192    14.081123  26.018164  19.451836
# 6            6  1986  14.543096  12.053836    14.205699  26.320027  19.892849
# 7            7  1987  15.545890  12.007973    14.735425  26.754740  19.637973
# 8            8  1988  14.870902  11.621257    14.802568  26.498333  19.255082
# 9            9  1989  15.737918  11.656301    14.533781  26.202192  19.041562
# 10          10  1990  16.450274  13.056740    14.643096  26.249945  19.654219
# ...

# %%
df_change
# Out:
#           Tokyo  New York  Mexico City     Mumbai  Sao Paulo      Delhi  \
# year
# 1980  13.425643  9.485313    13.964524  26.293285  20.798843  23.843902
# 1981  -0.305327  0.126914    -0.242494  -0.121137  -0.481343  -0.079467
# 1982   0.942685 -0.066274     0.748466  -0.041671   0.317479  -0.654932
# 1983  -0.298575  0.804575    -0.219397  -0.418192   0.229890  -0.759973
# 1984  -0.856379 -0.400407    -0.661083   0.176929   0.244629   0.916885
# 1985   0.971064  0.179804    -0.214205  -0.092874  -0.418465   0.398732
# 1986  -0.596164 -0.164356     0.124575   0.301863   0.441014  -0.525205
# 1987   1.002795 -0.045863     0.529726   0.434712  -0.254877   1.480027
# 1988  -0.674989 -0.386716     0.067144  -0.256406  -0.382891  -0.534455
# 1989   0.867016  0.035045    -0.268787  -0.296142  -0.213520  -0.716778
# 1990   0.712356  1.400438     0.109315   0.047753   0.612658   0.108630
# 1991  -0.613644  0.059315     0.161479   0.049644  -0.142329   0.310877
# ...

# %%
file = df_change.transpose()
file
# Out:
# year                  1980       1981       1982      1983      1984  \
# Tokyo              13.4256  -0.305327   0.942685 -0.298575 -0.856379
# New York           9.48531   0.126914  -0.066274  0.804575 -0.400407
# Mexico City        13.9645  -0.242494   0.748466 -0.219397 -0.661083
# Mumbai             26.2933  -0.121137 -0.0416712 -0.418192  0.176929
# Sao Paulo          20.7988  -0.481343   0.317479   0.22989  0.244629
# ...                    ...        ...        ...       ...       ...
# Yangzhou           12.6144   0.537721   0.376137 -0.033863 -0.582072
# Novokuznetsk      -3.77578   0.528995   0.958466  0.355205  -3.50425
# Latakia            18.4452   0.417128  -0.816795  0.185863  0.197328
# Heroica Matamoros  21.7853   0.145508  0.0193699 -0.551178  0.355973
# Goteborg           4.90939 -0.0292441   0.985836  0.520137 -0.290062
#
# year                    1985       1986        1987        1988       1989  \
# ...

# %%
key = key.T
key
# Out:
# Key               city         city_ascii       lat       lng        country  \
# 0                Tokyo              Tokyo    35.685  139.7514          Japan
# 1             New York           New York   40.6943  -73.9249  United States
# 2          Mexico City        Mexico City   19.4424   -99.131         Mexico
# 3               Mumbai             Mumbai    19.017    72.857          India
# 4            São Paulo          Sao Paulo  -23.5587   -46.625         Brazil
# ..                 ...                ...       ...       ...            ...
# 995           Yangzhou           Yangzhou      32.4    119.43          China
# 996       Novokuznetsk       Novokuznetsk     53.75    87.115         Russia
# 997            Latakia            Latakia     35.54     35.78          Syria
# 998  Heroica Matamoros  Heroica Matamoros     25.88     -97.5         Mexico
# 999           Göteborg           Goteborg     57.75      12.0         Sweden
#
# Key iso2 iso3
# 0     JP  JPN
# ...

# %%
li = []
for c in file.index:
    temp = key.loc[key['city_ascii'] == c, 'country']
    li.append(temp[0])
file['country'] = li
li = []
for c in file.index:
    temp = key.loc[key['city_ascii'] == c, 'iso2']
    li.append(temp[0])
file['iso2'] = li
file
# Out:
# year                  1980       1981       1982      1983      1984  \
# Tokyo              13.4256  -0.305327   0.942685 -0.298575 -0.856379
# New York           9.48531   0.126914  -0.066274  0.804575 -0.400407
# Mexico City        13.9645  -0.242494   0.748466 -0.219397 -0.661083
# Mumbai             26.2933  -0.121137 -0.0416712 -0.418192  0.176929
# Sao Paulo          20.7988  -0.481343   0.317479   0.22989  0.244629
# ...                    ...        ...        ...       ...       ...
# Yangzhou           12.6144   0.537721   0.376137 -0.033863 -0.582072
# Novokuznetsk      -3.77578   0.528995   0.958466  0.355205  -3.50425
# Latakia            18.4452   0.417128  -0.816795  0.185863  0.197328
# Heroica Matamoros  21.7853   0.145508  0.0193699 -0.551178  0.355973
# Goteborg           4.90939 -0.0292441   0.985836  0.520137 -0.290062
#
# year                    1985       1986        1987        1988       1989  \
# ...

# %%
import geopandas as gpd

world = gpd.read_file('D:\\Earth.Org\\TemperatureChange_Cities\\ne_50m_admin_0_countries\\ne_50m_admin_0_countries.shp')
world.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
# ...

# %%
world['ISO_A2']
# Out:
# 0       ZW
# 1       ZM
# 2       YE
# 3       VN
# 4       VE
#       ...
# 236     AL
# 237     AF
# 238    -99
# 239     AQ
# 240     SX
# Name: ISO_A2, Length: 241, dtype: object

# %%
world = world[['ISO_A2', 'CONTINENT']]

li = []for c in file.i['iso2']    temp = world.loc[]world[]'NISO_A2 == c, ''CONTINENT
  
    
temp = temp.values     if temp.size == 0:
         pli.append(one))     else:  prin    tli.append(val[]0
   file['Continent'] = li
ffile[file.index == 'Barcelona'][1980].values[0][0]
# Out:
# 13.55117119271678
